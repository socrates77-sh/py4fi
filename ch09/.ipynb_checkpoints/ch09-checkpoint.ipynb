# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def f(x):
    return np.sin(x) + 0.5 * x

# %%
x = np.linspace(-2 * np.pi, 2 * np.pi, 50)

# %%
plt.plot(x, f(x), 'b')
plt.grid(True)
plt.xlabel('x')
plt.ylabel('f(x)')

# %%
reg = np.polyfit(x, f(x), deg=7)
ry = np.polyval(reg, x)

# %%
reg
# Out:
# array([ -5.47508597e-05,   7.27924904e-19,   4.99394999e-03,
#         -2.59540643e-17,  -1.35368487e-01,   3.51322359e-16,
#          1.41870278e+00,  -5.32206157e-16])

# %%
plt.plot(x, f(x), 'b', label='f(x)')
plt.plot(x, ry, 'r.', label='regression')
plt.legend(loc=0)
plt.grid(True)
plt.xlabel('x')
plt.ylabel('f(x)')

# %%
np.sum((f(x) - ry) ** 2) / len(x)
# Out:
# 0.0017769134759517819

# %%
matrix = np.zeros((3 + 1, len(x)))
matrix[3, :] = x ** 3
matrix[2, :] = x ** 2
matrix[1, :] = x
matrix[0, :] = 1

# %%
reg = np.linalg.lstsq(matrix.T, f(x))[0]

# %%
ry = np.dot(reg, matrix)

# %%
plt.plot(x, f(x), 'b', label='f(x)')
plt.plot(x, ry, 'r.', label='regression')
plt.legend(loc=0)
plt.grid(True)
plt.xlabel('x')
plt.ylabel('f(x)')

# %%
matrix[3, :] = np.sin(x)
reg = np.linalg.lstsq(matrix.T, f(x))[0]
ry = np.dot(reg, matrix)

# %%
plt.plot(x, f(x), 'b', label='f(x)')
plt.plot(x, ry, 'r.', label='regression')
plt.legend(loc=0)
plt.grid(True)
plt.xlabel('x')
plt.ylabel('f(x)')

# %%
np.allclose(f(x), ry)
# Out:
# True

# %%
np.sum((f(x) - ry) ** 2) / len(x)
# Out:
# 5.7266371338387827e-31

# %%
xn = np.linspace(-2 * np.pi, 2 * np.pi, 50)
xn = xn + 0.15 * np.random.standard_normal(len(xn))
yn = f(xn) + 0.25 * np.random.standard_normal(len(xn))

# %%
reg = np.polyfit(xn, yn, 7)
ry = np.polyval(reg, xn)

# %%
plt.plot(xn, yn, 'b^', label='f(x)')
plt.plot(xn, ry, 'ro', label='regression')
plt.legend(loc=0)
plt.grid(True)
plt.xlabel('x')
plt.ylabel('f(x)')

# %%
xu = np.random.rand(50) * 4 * np.pi - 2 * np.pi
yu = f(xu)

# %%
print(xu[:10].round(2))
print(yu[:10].round(2))
# Out:
# [-3.74 -6.12 -4.52 -3.44  4.2   0.82  2.28 -1.    5.61 -2.49]
# [-1.31 -2.89 -1.28 -1.43  1.23  1.14  1.9  -1.34  2.18 -1.85]

# %%
reg = np.polyfit(xu, yu, 5)
ry = np.polyval(reg, xu)

# %%
plt.plot(xu, yu, 'b^', label='f(x)')
plt.plot(xu, ry, 'ro', label='regression')
plt.legend(loc=0)
plt.grid(True)
plt.xlabel('x')
plt.ylabel('f(x)')

# %%
def fm(p):
    x, y = p
    return np.sin(x) + 0.25 * x + np.sqrt(y) + 0.05 * y ** 2

# %%
x = np.linspace(0, 10, 20)
y = np.linspace(0, 10, 20)
X, Y = np.meshgrid(x, y)
  # generates 2-d grids out of the 1-d arrays
Z = fm((X, Y))
x = X.flatten()
y = Y.flatten()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib as mpl

fig = plt.figure(figsize=(9, 6))
ax = fig.gca(projection='3d')
surf = ax.plot_surface(X, Y, Z, rstride=2, cstride=2, cmap=mpl.cm.coolwarm,
        linewidth=0.5, antialiased=True)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('f(x, y)')
fig.colorbar(surf, shrink=0.5, aspect=5)

# %%
matrix = np.zeros((len(x), 6 + 1))
matrix[:, 6] = np.sqrt(y)
matrix[:, 5] = np.sin(x)
matrix[:, 4] = y ** 2
matrix[:, 3] = x ** 2
matrix[:, 2] = y
matrix[:, 1] = x
matrix[:, 0] = 1

# %%
import statsmodels.api as sm
# Out:
# e:\python34\lib\importlib\_bootstrap.py:321: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   return f(*args, **kwds)

# %%
model = sm.OLS(fm((x, y)), matrix).fit()

# %%
model.rsquared
# Out:
# 1.0

# %%
a = model.params
a
# Out:
# array([ -1.27431634e-15,   2.50000000e-01,   8.84147736e-17,
#         -3.65525761e-16,   5.00000000e-02,   1.00000000e+00,
#          1.00000000e+00])

# %%
def reg_func(a, p):
    x, y = p
    f6 = a[6] * np.sqrt(y)
    f5 = a[5] * np.sin(x)
    f4 = a[4] * y ** 2
    f3 = a[3] * x ** 2
    f2 = a[2] * y
    f1 = a[1] * x
    f0 = a[0] * 1
    return (f6 + f5 + f4 + f3 +
            f2 + f1 + f0)

# %%
RZ = reg_func(a, (X, Y))

# %%
fig = plt.figure(figsize=(9, 6))
ax = fig.gca(projection='3d')
surf1 = ax.plot_surface(X, Y, Z, rstride=2, cstride=2,
            cmap=mpl.cm.coolwarm, linewidth=0.5,
            antialiased=True)
surf2 = ax.plot_wireframe(X, Y, RZ, rstride=2, cstride=2,
                          label='regression')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('f(x, y)')
ax.legend()
fig.colorbar(surf, shrink=0.5, aspect=5)

# %%
import scipy.interpolate as spi

# %%
x = np.linspace(-2 * np.pi, 2 * np.pi, 25)

# %%
def f(x):
    return np.sin(x) + 0.5 * x

# %%
ipo = spi.splrep(x, f(x), k=1)

# %%
iy = spi.splev(x, ipo)

# %%
iy
# Out:
# array([-3.14159265, -2.37979327, -1.75196847, -1.35619449, -1.2283697 ,
#        -1.33259571, -1.57079633, -1.80899694, -1.91322295, -1.78539816,
#        -1.38962418, -0.76179939,  0.        ,  0.76179939,  1.38962418,
#         1.78539816,  1.91322295,  1.80899694,  1.57079633,  1.33259571,
#         1.2283697 ,  1.35619449,  1.75196847,  2.37979327,  3.14159265])

# %%
plt.plot(x, f(x), 'b', label='f(x)')
plt.plot(x, iy, 'r.', label='interpolation')
plt.legend(loc=0)
plt.grid(True)
plt.xlabel('x')
plt.ylabel('f(x)')

# %%
xd = np.linspace(1.0, 3.0, 50)
iyd = spi.splev(xd, ipo)

# %%
len(iyd)
# Out:
# 50

# %%
plt.plot(xd, f(xd), 'b', label='f(x)')
plt.plot(xd, iyd, 'r.', label='interpolation')
plt.legend(loc=0)
plt.grid(True)
plt.xlabel('x')
plt.ylabel('f(x)')

# %%
ipo = spi.splrep(x, f(x), k=3)
iyd = spi.splev(xd, ipo)

# %%
plt.plot(xd, f(xd), 'b', label='f(x)')
plt.plot(xd, iyd, 'r.', label='interpolation')
plt.legend(loc=0)
plt.grid(True)
plt.xlabel('x')
plt.ylabel('f(x)')

# %%
def fm(p):
    x, y = p
    return (np.sin(x) + 0.05 * x ** 2
          + np.sin(y) + 0.05 * y ** 2)

# %%
x = np.linspace(-10, 10, 50)
y = np.linspace(-10, 10, 50)
X, Y = np.meshgrid(x, y)
Z = fm((X, Y))

# %%
fig = plt.figure(figsize=(9, 6))
ax = fig.gca(projection='3d')
surf = ax.plot_surface(X, Y, Z, rstride=2, cstride=2, cmap=mpl.cm.coolwarm,
        linewidth=0.5, antialiased=True)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('f(x, y)')
fig.colorbar(surf, shrink=0.5, aspect=5)

# %%
import scipy.optimize as spo

# %%
def fo(p):
    x, y = p
    z = np.sin(x) + 0.05 * x ** 2 + np.sin(y) + 0.05 * y ** 2
    if output == True:
        print('%8.4f %8.4f %8.4f' % (x, y, z))
    return z

# %%
output = True
spo.brute(fo, ((-10, 10.1, 5), (-10, 10.1, 5)), finish=None)
# Out:
# -10.0000 -10.0000  11.0880
# -10.0000 -10.0000  11.0880
# -10.0000  -5.0000   7.7529
# -10.0000   0.0000   5.5440
# -10.0000   5.0000   5.8351
# -10.0000  10.0000  10.0000
#  -5.0000 -10.0000   7.7529
#  -5.0000  -5.0000   4.4178
#  -5.0000   0.0000   2.2089
#  -5.0000   5.0000   2.5000
#  -5.0000  10.0000   6.6649
#   0.0000 -10.0000   5.5440
#   0.0000  -5.0000   2.2089
#   0.0000   0.0000   0.0000
#   0.0000   5.0000   0.2911
#   0.0000  10.0000   4.4560
#   5.0000 -10.0000   5.8351
#   5.0000  -5.0000   2.5000
#   5.0000   0.0000   0.2911
#   5.0000   5.0000   0.5822
#   5.0000  10.0000   4.7471
#  10.0000 -10.0000  10.0000
#  10.0000  -5.0000   6.6649
#  10.0000   0.0000   4.4560
#  10.0000   5.0000   4.7471
#  10.0000  10.0000   8.9120
# array([ 0.,  0.])

# %%
output = False
opt1 = spo.brute(fo, ((-10, 10.1, 0.1), (-10, 10.1, 0.1)), finish=None)
opt1
# Out:
# array([-1.4, -1.4])

# %%
fm(opt1)
# Out:
# -1.7748994599769203

# %%
output = False
spo.fmin(fo, opt1, xtol=0.001, ftol=0.001, maxiter=15, maxfun=20)
# Out:
# Warning: Maximum number of function evaluations has been exceeded.
# array([-1.42702972, -1.42876755])

# %%
fm(opt2)
# Out:
# -1.7757246992239009

# %%
output = False
spo.fmin(fo, (2.0, 2.0), maxiter=250)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.015826
#          Iterations: 46
#          Function evaluations: 86
# array([ 4.2710728 ,  4.27106945])

# %%
from math import sqrt
def Eu(p):
    s, b = p
    return -(0.5 * sqrt(s * 15 + b * 5) + 0.5 * sqrt(s * 5 + b * 12))

# constraints
cons = ({'type': 'ineq', 'fun': lambda p: 100 - p[0] * 10 - p[1] * 10})
  # budget constraint
bnds = ((0, 1000), (0, 1000))  # uppper bounds large enough

# %%
result = spo.minimize(Eu, [5, 5], method='SLSQP',
                       bounds=bnds, constraints=cons)

# %%
result
# Out:
#      fun: -9.700883611487832
#      jac: array([-0.48508096, -0.48489535])
#  message: 'Optimization terminated successfully.'
#     nfev: 21
#      nit: 5
#     njev: 5
#   status: 0
#  success: True
#        x: array([ 8.02547122,  1.97452878])

# %%
import scipy.integrate as sci

# %%
def f(x):
    return np.sin(x) + 0.5 * x

# %%
a = 0.5  # left integral limit
b = 9.5  # right integral limit
x = np.linspace(0, 10)
y = f(x)

# %%
from matplotlib.patches import Polygon

fig, ax = plt.subplots(figsize=(7, 5))
plt.plot(x, y, 'b', linewidth=2)
plt.ylim(ymin=0)

# area under the function
# between lower and upper limit
Ix = np.linspace(a, b)
Iy = f(Ix)
verts = [(a, 0)] + list(zip(Ix, Iy)) + [(b, 0)]
poly = Polygon(verts, facecolor='0.7', edgecolor='0.5')
ax.add_patch(poly)

# labels
plt.text(0.75 * (a + b), 1.5, r"$\int_a^b f(x)dx$",
         horizontalalignment='center', fontsize=20)

plt.figtext(0.9, 0.075, '$x$')
plt.figtext(0.075, 0.9, '$f(x)$')

ax.set_xticks((a, b))
ax.set_xticklabels(('$a$', '$b$'))
ax.set_yticks([f(a), f(b)])
# Out:
# [<matplotlib.axis.YTick at 0x10292b70>, <matplotlib.axis.YTick at 0x10445290>]

# %%
sci.fixed_quad(f, a, b)[0]
# Out:
# 24.366995967084602

# %%
sci.quad(f, a, b)[0]
# Out:
# 24.374754718086752

# %%
sci.romberg(f, a, b)
# Out:
# 24.374754718086713

# %%
xi = np.linspace(0.5, 9.5, 25)

# %%
sci.trapz(f(xi), xi)
# Out:
# 24.352733271544516

# %%
sci.simps(f(xi), xi)
# Out:
# 24.374964184550748

# %%
for i in range(1, 20):
    np.random.seed(1000)
    x = np.random.random(i * 10) * (b - a) + a
    print(np.sum(f(x)) / len(x) * (b - a))
# Out:
# 24.8047622793
# 26.5229188983
# 26.2655475192
# 26.0277033994
# 24.9995418144
# 23.8818101416
# 23.5279122748
# 23.507857659
# 23.6723674607
# 23.6794104161
# 24.4244017079
# 24.2390053468
# 24.115396925
# 24.4241919876
# 23.9249330805
# 24.1948421203
# 24.1173483782
# 24.1006909297
# 23.7690510985

# %%
import sympy as sy

# %%
x = sy.Symbol('x')
y = sy.Symbol('y')

# %%
3 + sy.sqrt(x) - 4 ** 2
# Out:
# sqrt(x) - 13

# %%
f = x ** 2 + 3 + 0.5 * x ** 2 + 3 / 2

# %%
sy.simplify(f)
# Out:
# 1.5*x**2 + 4.5

# %%
from sympy import init_printing
init_printing()

# %%
f
# Out:
#      2
# 1.5⋅x  + 4.5

# %%
sy.sqrt(x) + 0.5
# Out:
# √x + 0.5

# %%
sy.solve(x ** 2 - 1)
# Out:
# [-1, 1]

# %%
sy.solve(x ** 2 - 1 - 3)
# Out:
# [-2, 2]

# %%
sy.solve(x ** 3 + 0.5 * x ** 2 - 1)
# Out:
# [0.858094329496553, -0.679047164748276 - 0.839206763026694⋅ⅈ, -0.6790471647482
# 76 + 0.839206763026694⋅ⅈ]

# %%
sy.solve(x ** 2 + y ** 2)
# Out:
# [{x: -ⅈ⋅y}, {x: ⅈ⋅y}]

# %%
a, b = sy.symbols('a b')

# %%
from sympy import init_printing
init_printing()

# %%
sy.Integral(sy.sin(x) + 0.5 * x, (x, a, b))
# Out:
# b
# ⌠
# ⎮ (0.5⋅x + sin(x)) dx
# ⌡
# a

# %%
int_func = sy.integrate(sy.sin(x) + 0.5 * x, x)

# %%
int_func
# Out:
#       2
# 0.25⋅x  - cos(x)

# %%
Fb = int_func.subs(x, 9.5).evalf()
Fa = int_func.subs(x, 0.5).evalf()

# %%
Fb - Fa
# Out:
# 24.3747547180867

# %%
int_func_limits = sy.integrate(sy.sin(x) + 0.5 * x, (x, a, b))
int_func_limits
# Out:
#         2         2
# - 0.25⋅a  + 0.25⋅b  + cos(a) - cos(b)

# %%
int_func_limits.subs({a : 0.5, b : 9.5}).evalf()
# Out:
# 24.3747547180868

# %%
sy.integrate(sy.sin(x) + 0.5 * x, (x, 0.5, 9.5))
# Out:
# 24.3747547180867

# %%
int_func.diff()
# Out:
# 0.5⋅x + sin(x)

# %%
f = (sy.sin(x) + 0.05 * x ** 2
   + sy.sin(y) + 0.05 * y ** 2)

# %%
del_x = sy.diff(f, x)
del_x
# Out:
# 0.1⋅x + cos(x)

# %%
del_y = sy.diff(f, y)
del_y
# Out:
# 0.1⋅y + cos(y)

# %%
xo = sy.nsolve(del_x, -1.5)
xo
# Out:
# -1.42755177876459

# %%
yo = sy.nsolve(del_y, -1.5)
yo
# Out:
# -1.42755177876459

# %%
f.subs({x : xo, y : yo}).evalf() 
  # global minimum
# Out:
# -1.77572565314742

# %%
xo = sy.nsolve(del_x, 1.5)
xo
# Out:
# 1.74632928225285

# %%
yo = sy.nsolve(del_y, 1.5)
yo
# Out:
# 1.74632928225285

# %%
f.subs({x : xo, y : yo}).evalf()
  # local minimum
# Out:
# 2.27423381055640
